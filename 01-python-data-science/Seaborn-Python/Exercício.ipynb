# %% [markdown]
# <a href="https://colab.research.google.com/github/danielduartt/Seaborn-Python/blob/main/Exerc%C3%ADcio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("/content/dados.csv", sep = ';')
df
# Out:
#      CODIGO                MUNICIPIO       PIB  VALOREMPENHO
# 0       106    SANTANA DO LIVRAMENTO  12240.76    1088666.10
# 1       113             SANTO ANGELO  16575.82     800669.92
# 2       118   SAO FRANCISCO DE ASSIS  12037.61     466122.80
# 3        13          CACAPAVA DO SUL  13674.54     485535.86
# 4       120              SAO GABRIEL  19912.38     533719.86
# ..      ...                      ...       ...           ...
# 182     372  SANTA VITORIA DO PALMAR  27170.89        760.00
# 183     107     SANTA BARBARA DO SUL  29654.02        365.00
# 184      54           GETULIO VARGAS  16876.33        233.01
# 185     382          NOVA SANTA RITA  25938.38        310.58
# 186      60      GUARANI DAS MISSOES  24363.31        172.13
#
# [187 rows x 4 columns]

# %%
df['PIB'].describe()
# Out:
# count       187.000000
# mean      19808.741337
# std       16984.223244
# min        8236.630000
# 25%       13621.455000
# 50%       17206.190000
# 75%       21429.165000
# max      223848.220000
# Name: PIB, dtype: float64

# %%
df['VALOREMPENHO'].describe()
# Out:
# count    1.870000e+02
# mean     1.299844e+05
# std      1.615491e+05
# min      1.721300e+02
# 25%      5.251718e+04
# 50%      8.422816e+04
# 75%      1.538961e+05
# max      1.442760e+06
# Name: VALOREMPENHO, dtype: float64

# %%
df.isnull().sum()
# Out:
# CODIGO          0
# MUNICIPIO       0
# PIB             0
# VALOREMPENHO    0
# dtype: int64

# %%
df.groupby(['MUNICIPIO']).size()
# Out:
# MUNICIPIO
# AGUDO                         1
# AJURICABA                     1
# ALECRIM                       1
# ALMIRANTE TAMANDARE DO SUL    1
# ALTO FELIZ                    1
#                              ..
# VERA CRUZ                     1
# VIADUTOS                      1
# VICTOR GRAEFF                 1
# VILA MARIA                    1
# VILA NOVA DO SUL              1
# Length: 177, dtype: int64

# %%
group_PIB = df.groupby(['MUNICIPIO'])['PIB'].sum()
group_PIB
# Out:
# MUNICIPIO
# AGUDO                         16444.80
# AJURICABA                     20784.67
# ALECRIM                       11431.18
# ALMIRANTE TAMANDARE DO SUL    26895.37
# ALTO FELIZ                    13209.54
#                                 ...
# VERA CRUZ                     18417.96
# VIADUTOS                      12520.25
# VICTOR GRAEFF                 26700.28
# VILA MARIA                    31104.22
# VILA NOVA DO SUL              13053.13
# Name: PIB, Length: 177, dtype: float64

# %%
plt.figure(figsize= (40,30)) #OH GOD!
group_PIB.plot.bar()
plt.tight_layout()
plt.show()

# %%
agrupados = df.sort_values("PIB").head(10)
agrupados = agrupados.iloc[:, 1:3]
agrupados
# Out:
#                MUNICIPIO       PIB
# 88             REDENTORA   8236.63
# 11       AMARAL FERRADOR   9216.87
# 15   ENCRUZILHADA DO SUL  10372.80
# 66      SENTINELA DO SUL  10477.52
# 89    SAO VALERIO DO SUL  10503.72
# 6               PIRATINI  10811.67
# 56                  MATA  10935.82
# 37  SANTANA DA BOA VISTA  11172.34
# 16               CANGUCU  11213.34
# 47             JAQUIRANA  11413.37

# %%
agrupados.plot.bar(x = 'MUNICIPIO', y = 'PIB') #Municipio com valor do PIP
# Out:
# <Axes: xlabel='MUNICIPIO'>

# %%
sns.histplot(df['PIB'], kde = True, color = 'r', bins = 20).set_title("PIB")
# Out:
# Text(0.5, 1.0, 'PIB')

# %%
sns.kdeplot(df['PIB']).set_title('PIB')
# Out:
# Text(0.5, 1.0, 'PIB')

# %%
sns.histplot(df['VALOREMPENHO'], color = 'green', kde = True, bins = 10 ).set_title("VALOREMPENHO")
# Out:
# Text(0.5, 1.0, 'VALOREMPENHO')

# %%
sns.kdeplot(df['VALOREMPENHO'], color = 'blue').set_title("VALOREMPENHO")
# Out:
# Text(0.5, 1.0, 'VALOREMPENHO')

# %%
sns.boxplot(df['VALOREMPENHO'], orient = 'v', color = 'r').set_title("VALOREMPENHO")
# Out:
# Text(0.5, 1.0, 'VALOREMPENHO')

# %%
plt.figure(figsize = (10,8))
plt.boxplot(df['VALOREMPENHO'], patch_artist= True, showfliers = True)
plt.tight_layout()
plt.show()

# %%
plt.figure()
plt.boxplot(df['PIB'], patch_artist= True, showfliers = True)
plt.tight_layout()
plt.show()

# %%
group_value = df.sort_values(["VALOREMPENHO"]).head(10)
group_value = group_value.iloc[:, 1:4]
group_value
# Out:
#                    MUNICIPIO       PIB  VALOREMPENHO
# 186      GUARANI DAS MISSOES  24363.31        172.13
# 184           GETULIO VARGAS  16876.33        233.01
# 185          NOVA SANTA RITA  25938.38        310.58
# 183     SANTA BARBARA DO SUL  29654.02        365.00
# 182  SANTA VITORIA DO PALMAR  27170.89        760.00
# 181              MATO LEITAO  27170.89        760.00
# 180  SANTA VITORIA DO PALMAR  17213.98        760.00
# 179              MATO LEITAO  17213.98        760.00
# 178                 SAO SEPE  15525.66       1186.00
# 177                     IJUI  23027.95       5920.00

# %%
group_value.plot.bar(x = 'MUNICIPIO', y = 'VALOREMPENHO', color = 'red')
# Out:
# <Axes: xlabel='MUNICIPIO'>
